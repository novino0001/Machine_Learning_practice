# %% [markdown]
# <a href="https://colab.research.google.com/github/novino0001/Machine_Learning_practice/blob/main/video_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 2.6.0+cu124

# %%
if torch.cuda.is_available():
    print("GPU is available!")
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
else:
    print("GPU not available. Using CPU.")
# Out:
# GPU is available!
# Using GPU: Tesla T4

# %%
# device = torch.device('cuda')
# print(device)
# Out:
# cuda

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using device:", device)
# Out:
# Using device: cuda

# %%
print(f"Model is running on: {next(model.parameters()).device}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b589c4c0051e> in <cell line: 0>()
# ----> 1 print(f"Model is running on: {next(model.parameters()).device}")
#
# NameError: name 'model' is not defined

# %%
# !pip install gdown

# %%
# !wget https://huggingface.co/spaces/jerryyan21/wav2lip_demo_test/resolve/main/wav2lip.pth -O Wav2Lip.pth
# Out:
# --2025-04-30 05:52:35--  https://huggingface.co/spaces/jerryyan21/wav2lip_demo_test/resolve/main/wav2lip.pth
# Resolving huggingface.co (huggingface.co)... 13.35.202.34, 13.35.202.121, 13.35.202.97, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.34|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !ls -lh Wav2Lip.pth
# Out:
# -rw-r--r-- 1 root root 416M Jan 18  2022 Wav2Lip.pth

# %%
# !git clone https://github.com/Rudrabha/Wav2Lip.git
# %cd Wav2Lip
# Out:
# fatal: destination path 'Wav2Lip' already exists and is not an empty directory.
# /content/Wav2Lip

# %%
# !ls
# Out:
# audio.py		filelists	     preprocess.py     sample_video.mp4
# checkpoints		harvard.wav	     __pycache__       temp
# color_syncnet_train.py	hparams.py	     README.md	       wav2lip_train.py
# consent-training.mp4	hq_wav2lip_train.py  requirements.txt
# evaluation		inference.py	     results
# face_detection		models		     sample_audio.wav

# %%
# !pip install -r requirements.txt
# !pip install imageio-ffmpeg==0.4.3
# Out:
# ...
#   Using cached librosa-0.7.0.tar.gz (1.6 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached numpy-1.17.1.zip (6.5 MB)
#   Preparing metadata (setup.py) ... done
# ...
# ERROR: Ignored the following yanked versions: 3.4.11.39, 3.4.17.61, 4.4.0.42, 4.4.0.44, 4.5.4.58, 4.5.5.62, 4.7.0.68
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ERROR: Could not find a version that satisfies the requirement opencv-python==4.1.0.25 (from versions: 3.4.0.14, 3.4.10.37, 3.4.11.41, 3.4.11.43, 3.4.11.45, 3.4.13.47, 3.4.15.55, 3.4.16.57, 3.4.16.59, 3.4.17.63, 3.4.18.65, 4.3.0.38, 4.4.0.40, 4.4.0.46, 4.5.1.48, 4.5.3.56, 4.5.4.60, 4.5.5.64, 4.6.0.66, 4.7.0.72, 4.8.0.74, 4.8.0.76, 4.8.1.78, 4.9.0.80, 4.10.0.82, 4.10.0.84, 4.11.0.86)
# ...

# %%
# !mv ../Wav2Lip.pth ./checkpoints/

# %%
# !gdown https://ai-call-resources.s3.us-east-1.amazonaws.com/videos/consent-training.mp4 -O consent-training.mp4
# !gdown --fuzzy "https://drive.google.com/file/d/1rhWVMOyB0Jo-2WNpPaZ3oihn8tylKrvA/view?usp=sharing" -O harvard.wav
# Out:
# Downloading...
# From: https://ai-call-resources.s3.us-east-1.amazonaws.com/videos/consent-training.mp4
# To: /content/Wav2Lip/consent-training.mp4
# 100% 22.6M/22.6M [00:02<00:00, 8.00MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1rhWVMOyB0Jo-2WNpPaZ3oihn8tylKrvA
# To: /content/Wav2Lip/harvard.wav
# 100% 3.25M/3.25M [00:00<00:00, 150MB/s]

# %%
# !pip install librosa==0.8.1

# %%
# !pip install numpy==1.23.5

# %%
# !python inference.py --checkpoint_path checkpoints/Wav2Lip.pth --face consent-training.mp4 --audio harvard.wav
# Out:
# Using cuda for inference.
# Reading video frames...
# Number of frames available for inference: 523
# (80, 1469)
# Length of mel chunks: 547
#   0% 0/5 [00:00<?, ?it/s]Downloading: "https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth" to /root/.cache/torch/hub/checkpoints/s3fd-619a316812.pth
#
#   0% 0.00/85.7M [00:00<?, ?B/s]
#   0% 128k/85.7M [00:00<05:28, 273kB/s]
#   0% 256k/85.7M [00:00<03:19, 450kB/s]
#   1% 512k/85.7M [00:00<01:48, 825kB/s]
#   1% 1.00M/85.7M [00:00<00:55, 1.59MB/s]
#   2% 2.00M/85.7M [00:01<00:28, 3.11MB/s]
#   5% 4.00M/85.7M [00:01<00:13, 6.16MB/s]
#   9% 7.50M/85.7M [00:01<00:07, 11.3MB/s]
#  12% 10.4M/85.7M [00:01<00:05, 13.6MB/s]
#  16% 13.6M/85.7M [00:01<00:04, 15.9MB/s]
#  20% 17.1M/85.7M [00:01<00:03, 18.0MB/s]
#  24% 20.4M/85.7M [00:02<00:03, 19.0MB/s]
#  28% 23.8M/85.7M [00:02<00:03, 19.9MB/s]
#  32% 27.0M/85.7M [00:02<00:03, 20.4MB/s]
#  35% 30.4M/85.7M [00:02<00:02, 20.9MB/s]
#  39% 33.6M/85.7M [00:02<00:02, 21.0MB/s]
# ...

# %%
# !python inference.py --checkpoint_path checkpoints/Wav2Lip.pth --face consent-training.mp4 --audio harvard.wav
# Out:
# Using cuda for inference.
# Reading video frames...
# Number of frames available for inference: 523
# (80, 1469)
# Length of mel chunks: 547
#   0% 0/5 [00:00<?, ?it/s]
#   0% 0/33 [00:11<?, ?it/s]
# Recovering from OOM error; New batch size: 8
#
#   0% 0/66 [00:00<?, ?it/s]
#   2% 1/66 [03:21<3:37:52, 201.12s/it]
#   3% 2/66 [03:24<1:30:19, 84.67s/it]
#   5% 3/66 [03:27<49:51, 47.48s/it]
#   6% 4/66 [03:30<30:58, 29.98s/it]
#   8% 5/66 [03:33<20:38, 20.31s/it]
#   9% 6/66 [03:37<14:29, 14.49s/it]
#  11% 7/66 [03:40<10:37, 10.80s/it]
#  12% 8/66 [03:43<08:05,  8.36s/it]
#  14% 9/66 [03:46<06:23,  6.73s/it]
#  15% 10/66 [03:49<05:15,  5.63s/it]
#  17% 11/66 [03:53<04:33,  4.98s/it]
#  18% 12/66 [03:56<03:59,  4.43s/it]
#  20% 13/66 [03:59<03:34,  4.04s/it]
#  21% 14/66 [04:02<03:17,  3.80s/it]
#  23% 15/66 [04:06<03:09,  3.72s/it]
#  24% 16/66 [04:09<02:57,  3.55s/it]
#  26% 17/66 [04:12<02:47,  3.43s/it]
#  27% 18/66 [04:15<02:41,  3.37s/it]
#  29% 19/66 [04:19<02:36,  3.32s/it]
# ...

# %%
# !ls
# Out:
# audio.py		filelists	     preprocess.py     sample_video.mp4
# checkpoints		harvard.wav	     __pycache__       temp
# color_syncnet_train.py	hparams.py	     README.md	       wav2lip_train.py
# consent-training.mp4	hq_wav2lip_train.py  requirements.txt
# evaluation		inference.py	     results
# face_detection		models		     sample_audio.wav

# %%
# %cd results
# Out:
# /content/Wav2Lip/results

# %%
# !ls
# Out:
# README.md  result_voice.mp4

# %%
from IPython.display import Video

Video("result_voice.mp4")
# Out:
# <video src="result_voice.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# !du -sh result_voice.mp4
# Out:
# 9.4M	result_voice.mp4

# %%
from google.colab import files
files.download('result_voice.mp4')
